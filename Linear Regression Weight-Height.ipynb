# %% [markdown]
# **Linear Regression with Keras and Tensorflow**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from keras.models import Sequential
from keras.layers import Dense 
from keras.optimizers import Adam, SGD

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
print(os.listdir("../input"))
# Out:
# []

# %%
df=pd.read_csv('../input/weight-height/weight-height.csv')
X=df[['Height']].values
y_true=df[['Weight']].values

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.3), 'mean_squared_error')

# %%
model.fit(X,y_true, epochs=40, batch_size=110)
# Out:
# Epoch 1/40
# 91/91 [==============================] - 0s 1ms/step - loss: 204.0680
# Epoch 2/40
# 91/91 [==============================] - 0s 1ms/step - loss: 152.0147
# Epoch 3/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.7929
# Epoch 4/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.9918
# Epoch 5/40
# 91/91 [==============================] - 0s 1ms/step - loss: 160.6189
# Epoch 6/40
# 91/91 [==============================] - 0s 1ms/step - loss: 158.0832
# Epoch 7/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.0391
# Epoch 8/40
# 91/91 [==============================] - 0s 1ms/step - loss: 162.5564
# Epoch 9/40
# 91/91 [==============================] - 0s 1ms/step - loss: 153.6206
# Epoch 10/40
# 91/91 [==============================] - 0s 1ms/step - loss: 155.2178
# Epoch 11/40
# 91/91 [==============================] - 0s 1ms/step - loss: 156.5646
# Epoch 12/40
# 91/91 [==============================] - 0s 1ms/step - loss: 161.6958
# Epoch 13/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.9435
# Epoch 14/40
# 91/91 [==============================] - 0s 1ms/step - loss: 159.9393
# Epoch 15/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.2672
# Epoch 16/40
# 91/91 [==============================] - 0s 1ms/step - loss: 157.0441
# Epoch 17/40
# 91/91 [==============================] - 0s 2ms/step - loss: 153.5790
# Epoch 18/40
# 91/91 [==============================] - 0s 1ms/step - loss: 159.3664
# Epoch 19/40
# 91/91 [==============================] - 0s 1ms/step - loss: 160.6828
# Epoch 20/40
# 91/91 [==============================] - 0s 1ms/step - loss: 157.8456
# Epoch 21/40
# 91/91 [==============================] - 0s 1ms/step - loss: 159.4893
# Epoch 22/40
# 91/91 [==============================] - 0s 1ms/step - loss: 160.1829
# Epoch 23/40
# 91/91 [==============================] - 0s 1ms/step - loss: 153.0158
# Epoch 24/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.8044
# Epoch 25/40
# 91/91 [==============================] - 0s 1ms/step - loss: 156.7248
# Epoch 26/40
# 91/91 [==============================] - 0s 1ms/step - loss: 155.7788
# Epoch 27/40
# 91/91 [==============================] - 0s 1ms/step - loss: 160.6523
# Epoch 28/40
# 91/91 [==============================] - 0s 1ms/step - loss: 155.8692
# Epoch 29/40
# 91/91 [==============================] - 0s 1ms/step - loss: 158.5880
# Epoch 30/40
# 91/91 [==============================] - 0s 1ms/step - loss: 154.9462
# Epoch 31/40
# 91/91 [==============================] - 0s 2ms/step - loss: 159.2867
# Epoch 32/40
# 91/91 [==============================] - 0s 1ms/step - loss: 162.4816
# Epoch 33/40
# 91/91 [==============================] - 0s 1ms/step - loss: 160.1337
# Epoch 34/40
# 91/91 [==============================] - 0s 1ms/step - loss: 156.5207
# Epoch 35/40
# 91/91 [==============================] - 0s 1ms/step - loss: 159.7405
# Epoch 36/40
# 91/91 [==============================] - 0s 1ms/step - loss: 158.3985
# Epoch 37/40
# 91/91 [==============================] - 0s 1ms/step - loss: 159.4919
# Epoch 38/40
# 91/91 [==============================] - 0s 1ms/step - loss: 153.6873
# Epoch 39/40
# 91/91 [==============================] - 0s 1ms/step - loss: 155.6148
# Epoch 40/40
# 91/91 [==============================] - 0s 1ms/step - loss: 156.7170

# %%
y_pred= model.predict(X)

# %%
df.plot(kind='scatter',
       x='Height',
       y='Weight', title='Weight and Height in adults')
plt.plot(X, y_pred, color='red', linewidth=3)

# %%
w,b=model.get_weights()

# %%
w
# Out:
# array([[7.742808]], dtype=float32)

# %%
b
# Out:
# array([-340.0398], dtype=float32)
